# %%
import pandas as pd
import numpy as np
import seaborn as sns
df=pd.read_csv('webmd.csv.zip')
np.random.seed(0)

# %%
df.head(10)
# Out:
#           Age                      Condition        Date  \
# 0  75 or over                    Stuffy Nose   9/21/2014
# 1       25-34                  Cold Symptoms   1/13/2011
# 2       65-74                          Other   7/16/2012
# 3  75 or over                          Other   9/23/2010
# 4       35-44                          Other    1/6/2009
# 5       55-64                          Other   7/19/2008
# 6       25-34                  Birth Control   6/15/2017
# 7       45-54  Disease of Ovaries with Cysts   1/30/2017
# 8       25-34                           Acne   4/27/2016
# 9       55-64                    Stuffy Nose  10/29/2012
#
#                                       Drug  DrugId  EaseofUse  Effectiveness  \
# 0                             25dph-7.5peh  146724          5              5
# 1                             25dph-7.5peh  146724          5              5
# 2             warfarin (bulk) 100 % powder  144731          2              3
# ...

# %%
cols_to_drop=['Condition','Date','Reviews']
df=df.drop(cols_to_drop,axis=1)

# %%
n_data.head(3 )
# Out:
#           Age                          Drug  DrugId  EaseofUse  Effectiveness  \
# 0  75 or over                  25dph-7.5peh  146724          5              5
# 1       25-34                  25dph-7.5peh  146724          5              5
# 2       65-74  warfarin (bulk) 100 % powder  144731          2              3
#
#    Satisfaction     Sex                                              Sides  \
# 0             5    Male  Drowsiness,  dizziness ,  dry mouth /nose/thro...
# 1             5  Female  Drowsiness,  dizziness ,  dry mouth /nose/thro...
# 2             3  Female
#
#    UsefulCount
# 0            0
# 1            1
# 2            0

# %%
sns.heatmap(n_data.isnull())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362806 entries, 0 to 362805
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Age            362806 non-null  object
#  1   Drug           362806 non-null  object
#  2   DrugId         362806 non-null  int64
#  3   EaseofUse      362806 non-null  int64
#  4   Effectiveness  362806 non-null  int64
#  5   Satisfaction   362806 non-null  int64
#  6   Sex            362806 non-null  object
#  7   Sides          362806 non-null  object
#  8   UsefulCount    362806 non-null  int64
# dtypes: int64(5), object(4)
# memory usage: 24.9+ MB

# %%
aged=pd.get_dummies(df['Age'])
drugd=pd.get_dummies(df['Drug'])
sexd=pd.get_dummies(df['Sex'])
sided=pd.get_dummies(df['Sides'])

# %%
df=pd.concat((df,aged,drugd,sexd,sided),axis=1)

# %%
n_data.head()
# Out:
#           Age                          Drug  DrugId  EaseofUse  Effectiveness  \
# 0  75 or over                  25dph-7.5peh  146724          5              5
# 1       25-34                  25dph-7.5peh  146724          5              5
# 2       65-74  warfarin (bulk) 100 % powder  144731          2              3
# 3  75 or over  warfarin (bulk) 100 % powder  144731          2              2
# 4       35-44  warfarin (bulk) 100 % powder  144731          1              1
#
#    Satisfaction     Sex                                              Sides  \
# 0             5    Male  Drowsiness,  dizziness ,  dry mouth /nose/thro...
# 1             5  Female  Drowsiness,  dizziness ,  dry mouth /nose/thro...
# 2             3  Female
# 3             1  Female
# 4             1    Male
#
#    UsefulCount     ...  \
# 0            0  0  ...
# 1            1  0  ...
# 2            0  0  ...
# 3            0  0  ...
# 4            1  0  ...
#
# ...

# %%
n_data=n_data.drop(['Drug','Sex','Sides'],axis=1)

# %%
X=n_data.values
Y=n_data['Effectiveness'].values

# %%
X=np.delete(X,1,axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=0)

# %%
from sklearn import tree
dt_clf=tree.DecisionTreeClassifier(max_depth=5)
dt_clf.fit(X_train,Y_train)
dt_clf.score(X_test,Y_test)
